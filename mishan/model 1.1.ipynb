# %%
# Support Vector Machine
# Importing the libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
cell_df = pd.read_csv('final.csv')

# %%
print("total cells before :\n",cell_df.columns)
feature_df = cell_df[[ 'lsa_similarity' , 'fingerprint_similarity']]  #'Gender',
print("\ntotal cells after :\n",feature_df.columns)
# Out:
# total cells before :
#  Index(['Original', 'Additional', 'label', 'trigram_similarity',
#        'bigram_similarity', 'word_similarity', 'word_similarity_using_wup_new',
#        'fingerprint_similarity', 'lsa_similarity'],
#       dtype='object')
#
# total cells after :
#  Index(['lsa_similarity', 'fingerprint_similarity'], dtype='object')

# %%
#independent variables
x= np.asarray(feature_df)

#dependent variables 
y= np.asarray(cell_df['label'])

#print 
print("x : \n",x[0:5])
print("y : \n",y[0:5])
# Out:
# x :
#  [[0.236      0.3875    ]
#  [0.214      0.37804878]
#  [0.478      0.53623188]
#  [0.78       0.57534247]
#  [0.964      0.94736842]]
# y :
#  [0 0 1 1 1]

# %% [markdown]
# # dividing the data into train/test data

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.9,random_state=4)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
x_train = sc_X.fit_transform(x_train)
x_test = sc_X.transform(x_test)

# %% [markdown]
# # Creating SVM Model from sklearn

# %% [markdown]
# ![types_of_svm_sklearn.png](attachment:types_of_svm_sklearn.png)

# %%
from sklearn import svm

#SVC = support vector classifer

classifier = svm.SVC(kernel='linear', gamma = 'auto', C = 18)
#c is the penalty imposed on the incorrectly places datapoints

# %% [markdown]
# # training the data

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC(C=18, gamma='auto', kernel='linear')

# %% [markdown]
# # testing the data

# %%
y_pred = classifier.predict(x_test)

# %% [markdown]
# # result

# %%
from sklearn import metrics
print("accuracy score with linear kernel :")
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# accuracy score with linear kernel :
# 0.8604651162790697

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85        34
#            1       1.00      0.77      0.87        52
#
#     accuracy                           0.86        86
#    macro avg       0.87      0.88      0.86        86
# weighted avg       0.90      0.86      0.86        86
